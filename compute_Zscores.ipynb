# %%
import numpy as np

from plot_utils import plot_ref_data

# %%
# load pairs of files with the values of the test statistic under the null and under the alternative
# make sure to match dimesionality, size of the training set (for MoG data) and sample size

ref = np.load("JetData_gen_as_ref/null/ND200000.npy")
data = np.load("JetData_gen_as_ref/alternatives/ND200000.npy")

print(ref.shape)
print(data.shape)
# Out:
# (200,)
# (40,)

# %%
# compute p values and Z scores 
# plot the distribution of the test staistic under the null and the alternative
# note that the empirical Z scores saturates at 2.578 as it is estimated with 200 points under the null

plot_ref_data(ref, data, bins=12)
# Out:
# Empirical Z score
#
# median test statistic = 589.792
# p value = 4.975e-03
# Z score = 2.578
# Z = 2.58 (+0.00/-0.00)
#
# χ² Z score
#
# chi2 dof = 251.96218872070312
# p value = 3.915e-29
# Z score = 11.142
# Z = 11.14 (+0.96/-0.89)

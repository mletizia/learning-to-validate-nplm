# %%
import numpy as np
from plot_utils import plot_ref_with_fitted_chi2_ks

# %%
# load a file with the test statistic under the null
# plot the data and a chi2 with dof fitted to the data

ref = np.load("JetData_gen_as_ref/null/ND5000.npy")

plot_ref_with_fitted_chi2_ks(ref)
